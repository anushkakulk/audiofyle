# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import numpy as np
from sklearn.neighbors import NearestNeighbors
import webbrowser
from http.server import BaseHTTPRequestHandler, HTTPServer
import threading


class AuthHandler(BaseHTTPRequestHandler):
    def do_GET(self):
        self.send_response(200)
        self.send_header('Content-type', 'text/html')
        self.end_headers()

        code = self.path.split("?code=")[1]
        sp_oauth = self.server.sp_oauth
        token_info = sp_oauth.get_access_token(code)
        self.server.token_info = token_info

        self.wfile.write(
            b'Authentication successful. You can close this window.')

# local server for auth


def start_local_server(server, handler):
    server.serve_forever()


def authenticate():
    sp_oauth = SpotifyOAuth(client_id='', client_secret='',
                            redirect_uri='http://localhost:3000', scope='user-library-read')

    # new thread for server
    server = HTTPServer(('localhost', 3000), AuthHandler)
    server.sp_oauth = sp_oauth
    server_thread = threading.Thread(
        target=start_local_server, args=(server, AuthHandler))
    server_thread.start()

    # open the spotify oauth
    auth_url = sp_oauth.get_authorize_url()
    webbrowser.open_new(auth_url)
    server_thread.join()

    # yay authentication
    sp = spotipy.Spotify(auth=server.token_info['access_token'])
    return sp


# auth the spotipy
sp = authenticate()

# getters
user_playlists = sp.current_user_playlists()
liked_tracks = sp.current_user_saved_tracks()

# get features
track_features = []
for track in liked_tracks['items']:
    track_id = track['track']['id']
    features = sp.audio_features(tracks=[track_id])[0]
    track_features.append(
        [features['danceability'], features['energy'], features['acousticness']])

track_features = np.array(track_features)

# k nearest neighbors
knn_model = NearestNeighbors(n_neighbors=5, metric='euclidean')
knn_model.fit(track_features)

# just an example, mod if necessary [dance, energy, acousticness]
user_preferences = np.array([[0.7, 0.8, 0.2]])

# get the recommended!!
distances, indices = knn_model.kneighbors(user_preferences)

recommended_tracks = []
for index in indices.flatten():
    recommended_tracks.append(liked_tracks['items'][index]['track']['name'])

print("Recommended tracks:")
for track in recommended_tracks:
    print(track)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/q9/rltlgwkj7dq7qt_fbzv7sdcw0000gn/T/ipykernel_57395/520182201.py in <module>
#      51
#      52 # auth the spotipy
# ---> 53 sp = authenticate()
#      54
#      55 # getters
#
# /var/folders/q9/rltlgwkj7dq7qt_fbzv7sdcw0000gn/T/ipykernel_57395/520182201.py in authenticate()
#      34
#      35     # new thread for server
# ---> 36     server = HTTPServer(('localhost', 3000), AuthHandler)
#      37     server.sp_oauth = sp_oauth
#      38     server_thread = threading.Thread(
#
# ~/opt/anaconda3/lib/python3.10/socketserver.py in __init__(self, server_address, RequestHandlerClass, bind_and_activate)
#     450         if bind_and_activate:
#     451             try:
# --> 452                 self.server_bind()
#     453                 self.server_activate()
#     454             except:
#
# ~/opt/anaconda3/lib/python3.10/http/server.py in server_bind(self)
#     134     def server_bind(self):
#     135         """Override server_bind to store the server name."""
# --> 136         socketserver.TCPServer.server_bind(self)
#     137         host, port = self.server_address[:2]
#     138         self.server_name = socket.getfqdn(host)
#
# ~/opt/anaconda3/lib/python3.10/socketserver.py in server_bind(self)
#     464         if self.allow_reuse_address:
#     465             self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 466         self.socket.bind(self.server_address)
#     467         self.server_address = self.socket.getsockname()
#     468
#
# OSError: [Errno 48] Address already in use
# 127.0.0.1 - - [07/Sep/2023 14:38:09] "GET /_next/webpack-hmr HTTP/1.1" 200 -
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 51341)
# Traceback (most recent call last):
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 747, in __init__
#     self.handle()
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/http/server.py", line 425, in handle
#     self.handle_one_request()
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/http/server.py", line 413, in handle_one_request
#     method()
#   File "/var/folders/q9/rltlgwkj7dq7qt_fbzv7sdcw0000gn/T/ipykernel_57395/520182201.py", line 16, in do_GET
#     code = self.path.split("?code=")[1]
# IndexError: list index out of range
# ----------------------------------------
# 127.0.0.1 - - [07/Sep/2023 14:38:14] "GET /_next/webpack-hmr HTTP/1.1" 200 -
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 51344)
# Traceback (most recent call last):
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 747, in __init__
#     self.handle()
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/http/server.py", line 425, in handle
#     self.handle_one_request()
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/http/server.py", line 413, in handle_one_request
#     method()
#   File "/var/folders/q9/rltlgwkj7dq7qt_fbzv7sdcw0000gn/T/ipykernel_57395/520182201.py", line 16, in do_GET
#     code = self.path.split("?code=")[1]
# IndexError: list index out of range
# ----------------------------------------
# 127.0.0.1 - - [07/Sep/2023 14:38:19] "GET /_next/webpack-hmr HTTP/1.1" 200 -
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 51347)
# Traceback (most recent call last):
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/socketserver.py", line 747, in __init__
#     self.handle()
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/http/server.py", line 425, in handle
#     self.handle_one_request()
#   File "/Users/anushkakulkarni/opt/anaconda3/lib/python3.10/http/server.py", line 413, in handle_one_request
#     method()
#   File "/var/folders/q9/rltlgwkj7dq7qt_fbzv7sdcw0000gn/T/ipykernel_57395/520182201.py", line 16, in do_GET
#     code = self.path.split("?code=")[1]
# IndexError: list index out of range
# ----------------------------------------
